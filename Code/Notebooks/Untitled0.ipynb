# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

plt.rcParams["figure.figsize"] = [12,9]

# %%
rho_des = np.loadtxt('/home/manzotti/cosmosis/modules/limber/galaxies_delens/limber_spectra/rho_des.txt')
rho_cmb = np.loadtxt('/home/manzotti/cosmosis/modules/limber/galaxies_delens/limber_spectra/rho_cmb.txt')
rho_cib = np.loadtxt('/home/manzotti/cosmosis/modules/limber/galaxies_delens/limber_spectra/rho_cib.txt')
rho_comb_des_cib = np.loadtxt('/home/manzotti/cosmosis/modules/limber/galaxies_delens/limber_spectra/rho_comb_des_cib.txt')
rho_comb_des_cib_cmb = np.loadtxt('/home/manzotti/cosmosis/modules/limber/galaxies_delens/limber_spectra/rho_comb_des_cib_cmb.txt')
rho_des = np.loadtxt('/home/manzotti/cosmosis/modules/limber/galaxies_delens/limber_spectra/rho_euclid.txt')
rho_lsst = np.loadtxt('/home/manzotti/cosmosis/modules/limber/galaxies_delens/limber_spectra/rho_lsst.txt')
rho_ska01 = np.loadtxt('/home/manzotti/cosmosis/modules/limber/galaxies_delens/limber_spectra/rho_ska01.txt')
rho_ska1 = np.loadtxt('/home/manzotti/cosmosis/modules/limber/galaxies_delens/limber_spectra/rho_ska1.txt')
rho_ska5 = np.loadtxt('/home/manzotti/cosmosis/modules/limber/galaxies_delens/limber_spectra/rho_ska5.txt')
rho_ska10 = np.loadtxt('/home/manzotti/cosmosis/modules/limber/galaxies_delens/limber_spectra/rho_ska10.txt')
rho_lsst = np.loadtxt('/home/manzotti/cosmosis/modules/limber/galaxies_delens/limber_spectra/rho_lsst.txt')
rho_euclid = np.loadtxt('/home/manzotti/cosmosis/modules/limber/galaxies_delens/limber_spectra/rho_euclid.txt')

# %%
plt.plot(rho_ska10[:,0],rho_ska10[:,1])
plt.plot(rho_ska5[:,0],rho_ska5[:,1])
plt.plot(rho_ska1[:,0],rho_ska1[:,1])
plt.plot(rho_euclid[:,0],rho_euclid[:,1])
plt.plot(rho_lsst[:,0],rho_lsst[:,1])
plt.plot(rho_ska01[:,0],rho_ska01[:,1])
plt.xlim(0,1000)
# Out:
# (0, 1000)

# %%
plt.plot(rho_cib[:,0],rho_cib[:,1])

# %%
cosmosis_dir = '/home/manzotti/cosmosis/'
inifile = '/home/manzotti/cosmosis/modules/limber/galaxies_delens.ini'
n_slices = 2
output_dir = '/modules/limber/galaxies_delens'



cl_ska10_k = np.loadtxt(cosmosis_dir + output_dir + '/limber_spectra/cl' + 'ska10' + 'k_delens.txt')
cl_ska5_k = np.loadtxt(cosmosis_dir + output_dir + '/limber_spectra/cl' + 'ska5' + 'k_delens.txt')
cl_ska1_k = np.loadtxt(cosmosis_dir + output_dir + '/limber_spectra/cl' + 'ska1' + 'k_delens.txt')
cl_ska01_k = np.loadtxt(cosmosis_dir + output_dir + '/limber_spectra/cl' + 'ska01' + 'k_delens.txt')

cl_ska10 = np.loadtxt(cosmosis_dir + output_dir + '/limber_spectra/cl' + 'ska10ska10' + '_delens.txt')
cl_ska5 = np.loadtxt(cosmosis_dir + output_dir + '/limber_spectra/cl' + 'ska5ska5' + '_delens.txt')
cl_ska1 = np.loadtxt(cosmosis_dir + output_dir + '/limber_spectra/cl' + 'ska1ska1' + '_delens.txt')
cl_ska01 = np.loadtxt(cosmosis_dir + output_dir + '/limber_spectra/cl' + 'ska01ska01' + '_delens.txt')

cl_lsst_k = np.loadtxt(cosmosis_dir + output_dir + '/limber_spectra/cl' + 'lsst' + 'k_delens.txt')
cl_euclid_k = np.loadtxt(cosmosis_dir + output_dir + '/limber_spectra/cl' + 'euclid' + 'k_delens.txt')

cl_euclid = np.loadtxt(cosmosis_dir + output_dir + '/limber_spectra/cl' + 'euclideuclid' + '_delens.txt')
cl_lsst = np.loadtxt(cosmosis_dir + output_dir + '/limber_spectra/cl' + 'lsstlsst' + '_delens.txt')
lbins = np.loadtxt(cosmosis_dir + output_dir + '/limber_spectra/ells__delens.txt')

# %%
plt.loglog(lbins,cl_ska01)

plt.loglog(lbins,cl_lsst)

# %%
from scipy.interpolate import RectBivariateSpline, interp1d

ells_cmb = np.loadtxt('/home/manzotti/cosmosis/modules/limber/galaxies_delens/' + 'cmb_cl/ell.txt')


cib_res = np.loadtxt('/home/manzotti/cosmosis/modules/limber/galaxies_delens/limber_spectra/cbb_res_cib.txt')
clbb_th = np.loadtxt(
    '/home/manzotti/cosmosis/modules/limber/galaxies_delens/cmb_cl/bb.txt')
clbb_th *= 2. * np.pi / (ells_cmb.astype(float) * (ells_cmb.astype(float) + 1.))

surveys = ['test','cib', 'des', 'comb_des_cib', 'comb_des_cib_cmb', 'ska10', 'ska5', 'ska1', 'ska01']

rho = {}

clbb_res = {}
clbb_res2 = {}
clbb_res3 = {}



cbb_res_ls = np.loadtxt(
    '/home/manzotti/cosmosis/modules/limber/galaxies_delens/limber_spectra/cbb_res_ls.txt')
clbb_th_fun = interp1d(ells_cmb[:], clbb_th[:])

clbb_test = np.loadtxt('/home/manzotti/cosmosis/modules/limber/galaxies_delens/limber_spectra/cbb.txt')
for label in surveys:
    clbb_res[label] = np.loadtxt(
        '/home/manzotti/cosmosis/modules/limber/galaxies_delens/limber_spectra/cbb_res_' + label + '.txt')
for label in surveys:
    clbb_res2[label] = np.loadtxt(
        '/home/manzotti/cosmosis/modules/limber/galaxies_delens/limber_spectra/cbb_res_' + label + 'test3.txt')

for label in surveys:
    clbb_res3[label] = np.loadtxt(
        '/home/manzotti/cosmosis/modules/limber/galaxies_delens/limber_spectra/cbb_res_' + label + 'test2.txt')

# %%
plt.plot(ells_cmb,clbb_th)
plt.plot(cbb_res_ls,clbb_res['cib']*2.5)
plt.xlim(0,300)
# Out:
# (0, 300)

# %%
cib_res2 = np.loadtxt('/home/manzotti/cosmosis/modules/limber/galaxies_delens/limber_spectra/cbb_res_cibtest2.txt')
cib_res3 = np.loadtxt('/home/manzotti/cosmosis/modules/limber/galaxies_delens/limber_spectra/cbb_res_cibtest3.txt')

# %%
plt.plot(cbb_res_ls,clbb_res['test'])
# plt.plot(cbb_res_ls,clbb_res['cib'])

plt.plot(clbb_res3['test'])
plt.plot(np.arange(4, 500, 10),clbb_res2['test'],'o')

plt.plot(cbb_res_ls,clbb_res['cib'])
# plt.plot(cbb_res_ls,clbb_res['cib'])

plt.plot(clbb_res3['cib'])
plt.plot(np.arange(4, 500, 10),clbb_res2['cib'],'o')



# plt.plot(cbb_res_ls,clbb_test)


# plt.plot(cib_res2)
# plt.plot(np.arange(4, 500, 10),cib_res3)
plt.plot(ells_cmb,clbb_th)

plt.xlim(10,500)
plt.ylim(0.0000001,0.0000025)
# Out:
# (1e-07, 2.5e-06)

# %%
plt.plot(cbb_res_ls,clbb_res['cib']/clbb_res['test'])
# plt.plot(cbb_res_ls,clbb_res['cib'])

plt.plot(clbb_res3['cib']/clbb_res3['test'])
plt.plot(np.arange(4, 500, 10),clbb_res2['cib']/clbb_res2['test'],'o')

plt.xlim(10,500)
# Out:
# /software/python-2.7-2015q2-el6-x86_64/lib/python2.7/site-packages/ipykernel/__main__.py:1: RuntimeWarning: invalid value encountered in divide
#   if __name__ == '__main__':
# (10, 500)

# %%
ells_cmb
# Out:
# array([  2.00000000e+00,   3.00000000e+00,   4.00000000e+00, ...,
#          4.99800000e+03,   4.99900000e+03,   5.00000000e+03])

# %%
lmin = 60

datadir = '/home/manzotti/cosmosis/modules/limber/galaxies_delens/'

clpp = np.loadtxt(datadir + 'cmb_cl/pp.txt')
clee = np.loadtxt(datadir + 'cmb_cl/ee.txt')
ells_cmb = np.loadtxt(datadir + 'cmb_cl/ell.txt')

clee *= 2. * np.pi / (ells_cmb.astype(float) * (ells_cmb.astype(float) + 1.))
clpp = clpp * 2. * np.pi / (ells_cmb.astype(float) * (ells_cmb.astype(float) + 1.))


lbins = np.logspace(1, 3.5, 190)


clbb_th = np.loadtxt(
    '/home/manzotti/cosmosis/modules/limber/galaxies_delens/cmb_cl/bb.txt')
clbb_th *= 2. * np.pi / (ells_cmb.astype(float) * (ells_cmb.astype(float) + 1.))
surveys = ['cib', 'des', 'comb_des_cib', 'comb_des_cib_cmb', 'ska10', 'ska5', 'ska1', 'ska01', 'lsst', 'euclid']

# B_res = Parallel(n_jobs=len(surveys), verbose=50)(delayed(
#     compute_res)(i) for i in surveys)

clee_fun = interp1d(ells_cmb, clee,bounds_error =False, fill_value =0.)
clpp_fun = interp1d(ells_cmb, clpp,bounds_error = False ,fill_value =0.)

# %%
def integrand(theta, ell, L):
#     print(ell,theta)
    return (ell / (2. * np.pi)**2 * (L * ell * np.cos(theta) - ell**2)**2 * clpp_fun(np.sqrt(L**2 + ell**2 
                                        - 2. * ell * L *np.cos(theta))) *clee_fun(ell) * (np.sin(2. * theta))**2)

# %%
import scipy.integrate as integrate

# %%
[integrate.dblquad(integrand, 2, 3000, lambda x: 0, lambda x:2*np.pi , args=(L,),epsrel=1.49e-10)[0] for L in np.arange(10,40,10) ]
# Out:
# [1.8422735318064558e-06, 1.851516375003935e-06, 1.8641133415447126e-06]

# %%
def integrand(ell):
    # print(ell**5 / 4. / np.pi * clpp(ell) * clee(ell))
    return ell**5 / 4. / np.pi * clpp_fun(ell) * clee_fun(ell)

# %%
integrate.quad(integrand, 4, 2500, limit=100, epsrel=1.49e-09)
# Out:
# (1.8423841283976908e-06, 2.1899237080354035e-09)

# %% [markdown]
# # test weak lensing

# %%
clkappacmb = np.loadtxt('/home/manzotti/cosmosis/modules/limber/galaxies_delens/limber_spectra/cldes_weakk_delens.txt')
cldeskappa = np.loadtxt('/home/manzotti/cosmosis/modules/limber/galaxies_delens/limber_spectra/cldes_weakdes_weak_delens.txt')


ell = np.loadtxt('/home/manzotti/cosmosis/modules/limber/galaxies_delens/limber_spectra/ells__delens.txt')

# %%
plt.plot(ell,ell*clkappacmb*1e6)
plt.xlim(0,2000)
# plt.ylim(0,1.6)
# Out:
# (0, 2000)

# %%
plt.plot(ell,ell**1*cldeskappa*1e7)
plt.xlim(0,2000)
# Out:
# (0, 2000)

# %%
clkcmb = np.loadtxt('/home/manzotti/cosmosis/modules/limber/galaxies_delens/limber_spectra/clk_delens.txt')
ell = np.loadtxt('/home/manzotti/cosmosis/modules/limber/galaxies_delens/limber_spectra/ells__delens.txt')

# %%
plt.plot(ell,clkcmb)
plt.plot(ells_cmb,ells_cmb**4/4 *clpp)
plt.xlim(0,2000)
# Out:
# (0, 2000)
